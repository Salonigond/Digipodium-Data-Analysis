# %%
x = 100

# %%
if x > 10 :
    print("x is greater than 10")
# Out:
# x is greater than 10

# %%
name = 'william shakespeare'

# %%
'Will' in name
# Out:
# False

# %%
'will' in name
# Out:
# True

# %%
if 'spear' in name:
    print('spear found in name')
# Out:
# spear found in name

# %%
'shake' in name
# Out:
# True

# %%
age = int(input('what is your age:'))
if age >= 18:
    print('you are an adult')
    print('you can vote')
else:
    print('you are a child')
    print('you cannot vote')
    print('you can vote in',18 - age, 'years')
# Out:
# you are a child
# you cannot vote
# you can vote in 6 years

# %%
# if elif else ladder
print('welcome to the ice crean shop')
flavour = input('what flavour do you whant?')
if flavour == 'vanilla':
    print('here is your vanilla ice cream')
elif flavour == 'chocolate':
    print('here is your chocolate ice cream') 
elif flavour == 'strawberry':
    print('here is your strawberry ice cream')
elif flavour == 'butterscotch':
    print('here is your butterscotch🍧')
else:
    print('sorry we do not have', flavour, 'flavour')
# Out:
# welcome to the ice crean shop
# here is your butterscotch🍧
